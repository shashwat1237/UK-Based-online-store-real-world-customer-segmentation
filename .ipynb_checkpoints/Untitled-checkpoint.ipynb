# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import re
import time
import math
from scipy.stats import skew
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score

# %%
def give_dictionary(desc):
    #desc=df["Description"].dropna()
    desc=desc.dropna()
    parts=[]
    dicti={}
    l=len(desc)
    for index in range(l):

        try:
            parts = re.split(r"[.,\-_\+/()\[\]{}\s]+", desc.iloc[index].lower().replace("'s"," "))
        except:
            print(desc.iloc[index])
        parts = [p for p in parts if p]
        
        for p in parts:
            try:
                dicti[p]+=(1)*100/l
            except:
                dicti[p]=1*100/l
    sorted_by_keys = sorted(dicti.items(), reverse=True,key=lambda item: item[1])
    return sorted_by_keys
def give_inv_cost(series):
    split_df = series.str.split("-", n=1, expand=True)
    split_df.columns=["Invoice","Price"]
    split_df["Price"]=split_df["Price"].astype(float)

    return split_df.groupby("Invoice")["Price"].sum().mean()
def custom_function(x):
    if x < 0:
        return math.exp(x)
    else:
        return 1 - math.exp(-x)

# %%
df=pd.read_csv("online_retail_2.csv",header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df=df[(df["Price"]>0)&(df["Quantity"]>0)]

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
print(df["InvoiceDate"].min())
df["Timestamp"]=(df["InvoiceDate"].dt.year*360)+(df["InvoiceDate"].dt.month*30)+df["InvoiceDate"].dt.day-723600
df["Month"]=df["InvoiceDate"].dt.month

df.drop(columns=["InvoiceDate"],inplace=True)
# Out:
# 2009-12-01 07:45:00

# %%
encoder1 = LabelEncoder()
df["Invoice"]=encoder1.fit_transform(df["Invoice"])
encoder2=LabelEncoder()
df["Country"]=encoder2.fit_transform(df["Country"])
encoder3=LabelEncoder()
df["Customer ID"]=encoder3.fit_transform(df["Customer ID"])
df.drop(columns=["StockCode"],inplace=True)
df["TotalStockCost"]=df["Quantity"]*df["Price"]

# %%
df_to_analyze1=df.copy()
df_to_analyze1["InvTCS_Combined"]=(df_to_analyze1["Invoice"].astype("str"))+"-"+(df_to_analyze1["TotalStockCost"].astype("str"))

# %%
df_to_analyze1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1041671 entries, 0 to 1067370
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Invoice          1041671 non-null  int64
#  1   Description      1041671 non-null  object
#  2   Quantity         1041671 non-null  int64
#  3   Price            1041671 non-null  float64
#  4   Customer ID      1041671 non-null  int64
#  5   Country          1041671 non-null  int64
#  6   Timestamp        1041671 non-null  int32
#  7   Month            1041671 non-null  int32
#  8   TotalStockCost   1041671 non-null  float64
#  9   InvTCS_Combined  1041671 non-null  object
# dtypes: float64(2), int32(2), int64(4), object(2)
# memory usage: 79.5+ MB

# %%
#scaler=StandardScaler()
at=time.time()
df_to_analyze1_grouped=df_to_analyze1.groupby("Customer ID").agg({"Quantity":["sum","mean",lambda x:x.quantile(0.25),lambda x:x.quantile(0.5),
                                                                             lambda x:x.quantile(0.75)],
"Timestamp":["min",lambda x:x.quantile(0.25),lambda x:x.quantile(0.5),lambda x:x.quantile(0.75),"max",lambda x:-1*skew(x)],"TotalStockCost":["sum","mean",
                                                                                                            lambda x:x.quantile(0.25),
                                                                                                            lambda x:x.quantile(0.5),
                                                                                                            lambda x:x.quantile(0.75)
                                                                                                                        ],
                                                                  "Price":["sum","mean",lambda x:x.quantile(0.25),lambda x:x.quantile(0.5),
                                                                          lambda x:x.quantile(0.75),
                                                                          ],
                                                                  "Description":lambda x:give_dictionary(x),
                                                                  "InvTCS_Combined":give_inv_cost,
                                                                  "Invoice":lambda x:len(x.unique())
}).reset_index()

print("yo")
print(time.time()-at)
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_2140\3150778558.py:5: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   "Timestamp":["min",lambda x:x.quantile(0.25),lambda x:x.quantile(0.5),lambda x:x.quantile(0.75),"max",lambda x:-1*skew(x)],"TotalStockCost":["sum","mean",
# yo
# 35.255115032196045

# %%
df_to_analyze1_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879 entries, 0 to 5878
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   (Customer ID, )                   5879 non-null   int64
#  1   (Quantity, sum)                   5879 non-null   int64
#  2   (Quantity, mean)                  5879 non-null   float64
#  3   (Quantity, <lambda_0>)            5879 non-null   float64
#  4   (Quantity, <lambda_1>)            5879 non-null   float64
#  5   (Quantity, <lambda_2>)            5879 non-null   float64
#  6   (Timestamp, min)                  5879 non-null   int32
#  7   (Timestamp, <lambda_0>)           5879 non-null   float64
#  8   (Timestamp, <lambda_1>)           5879 non-null   float64
#  9   (Timestamp, <lambda_2>)           5879 non-null   float64
#  10  (Timestamp, max)                  5879 non-null   int32
#  11  (Timestamp, <lambda_3>)           4189 non-null   float64
#  12  (TotalStockCost, sum)             5879 non-null   float64
#  13  (TotalStockCost, mean)            5879 non-null   float64
#  14  (TotalStockCost, <lambda_0>)      5879 non-null   float64
#  15  (TotalStockCost, <lambda_1>)      5879 non-null   float64
#  16  (TotalStockCost, <lambda_2>)      5879 non-null   float64
#  17  (Price, sum)                      5879 non-null   float64
#  18  (Price, mean)                     5879 non-null   float64
#  19  (Price, <lambda_0>)               5879 non-null   float64
#  20  (Price, <lambda_1>)               5879 non-null   float64
#  21  (Price, <lambda_2>)               5879 non-null   float64
#  22  (Description, <lambda>)           5879 non-null   object
#  23  (InvTCS_Combined, give_inv_cost)  5879 non-null   float64
#  24  (Invoice, <lambda>)               5879 non-null   int64
# dtypes: float64(19), int32(2), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
df_to_analyze1_grouped.columns=["CustomerID","Quantity_sum","Quantity_mean","Quantity_25q","Quantity_50q","Quantity_75q",
                               "Timestamp_min","Timestamp_25q","Timestamp_50q","Timestamp_75q","Timestamp_max","Timestamp_recency",
                               "TotalStockCost_sum","TotalStockCost_mean","TotalStockCost_25q","TotalStockCost_50q","TotalStockCost_75q",
                               "Price_sum","Price_mean","Price_25q","Price_50q","Price_75q",
                               "Description_keywords","AverageInvoiceCost","InvoiceCount"]

df_to_analyze1_grouped["Timestamp_diff"]=df_to_analyze1_grouped["Timestamp_max"]-df_to_analyze1_grouped["Timestamp_min"]
df_to_analyze1_grouped["Frequency"]=df_to_analyze1_grouped["InvoiceCount"]/df_to_analyze1_grouped["Timestamp_diff"]

# %%
df_to_analyze1_grouped["Timestamp_recency"]=df_to_analyze1_grouped["Timestamp_recency"].fillna(0)
df_to_analyze1_grouped["Frequency"] = df_to_analyze1_grouped["Frequency"].replace([np.inf, -np.inf], 0)
df_to_analyze1_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879 entries, 0 to 5878
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            5879 non-null   int64
#  1   Quantity_sum          5879 non-null   int64
#  2   Quantity_mean         5879 non-null   float64
#  3   Quantity_25q          5879 non-null   float64
#  4   Quantity_50q          5879 non-null   float64
#  5   Quantity_75q          5879 non-null   float64
#  6   Timestamp_min         5879 non-null   int32
#  7   Timestamp_25q         5879 non-null   float64
#  8   Timestamp_50q         5879 non-null   float64
#  9   Timestamp_75q         5879 non-null   float64
#  10  Timestamp_max         5879 non-null   int32
#  11  Timestamp_recency     5879 non-null   float64
#  12  TotalStockCost_sum    5879 non-null   float64
#  13  TotalStockCost_mean   5879 non-null   float64
#  14  TotalStockCost_25q    5879 non-null   float64
#  15  TotalStockCost_50q    5879 non-null   float64
#  16  TotalStockCost_75q    5879 non-null   float64
#  17  Price_sum             5879 non-null   float64
#  18  Price_mean            5879 non-null   float64
#  19  Price_25q             5879 non-null   float64
#  20  Price_50q             5879 non-null   float64
#  21  Price_75q             5879 non-null   float64
#  22  Description_keywords  5879 non-null   object
#  23  AverageInvoiceCost    5879 non-null   float64
#  24  InvoiceCount          5879 non-null   int64
#  25  Timestamp_diff        5879 non-null   int32
#  26  Frequency             5879 non-null   float64
# dtypes: float64(20), int32(3), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
"""s
a1=df_to_analyze1_grouped.sort_values(by="TotalStockCost_mean",ascending=False)["CustomerID"].head(588)
a2=df_to_analyze1_grouped.sort_values(by="TotalStockCost_sum",ascending=False)["CustomerID"].head(588)
a3=a2[a2.isin(a1.values)]                                                                                               
a4=df_to_analyze1_grouped.sort_values(by="Price_mean",ascending=False)["CustomerID"].head(588)
a5=a4[a4.isin(a2.values)]
print(len(a5))
"""

for_clustering=df_to_analyze1_grouped.drop(columns=["Description_keywords","CustomerID","Timestamp_25q",
                                                   "Timestamp_50q","Timestamp_75q","Timestamp_max","Timestamp_recency","Timestamp_min","Timestamp_diff"])

# %%
for_clustering.describe()
# Out:
#         Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count    5879.000000    5879.000000   5879.000000   5879.000000   5879.000000
# mean     1942.559279      25.310568     10.627275     15.733543     31.208751
# std     12908.465895     364.996108     60.437347     76.920455    541.699381
# min         1.000000       1.000000      1.000000      1.000000      1.000000
# 25%       190.000000       5.588863      2.000000      3.000000      6.000000
# 50%       492.000000       9.589744      4.000000      6.500000     12.000000
# 75%      1376.500000      14.149532      6.000000     12.000000     16.000000
# max    714139.000000   26999.000000   2000.000000   2520.000000  40498.000000
#
#        TotalStockCost_sum  TotalStockCost_mean  TotalStockCost_25q  \
# count        5.879000e+03          5879.000000         5879.000000
# mean         3.567438e+03            48.294107           23.792611
# std          4.458640e+04           780.111628          195.689766
# min          2.950000e+00             2.042182            0.390000
# 25%          3.487750e+02            11.472410            4.250000
# 50%          8.989600e+02            17.353684           12.500000
# 75%          2.309050e+03            24.193543           15.000000
# max          3.229539e+06         56157.500000        10953.500000
#
#        TotalStockCost_50q  TotalStockCost_75q     Price_sum    Price_mean  \
# count         5879.000000         5879.000000  5.879000e+03   5879.000000
# mean            30.470631           59.094281  7.223902e+02      8.580719
# std            203.625700         1148.075695  2.173638e+04    176.301198
# min              0.790000            1.875000  1.700000e-01      0.151333
# 25%              7.950000           14.750000  6.529000e+01      2.292084
# 50%             15.300000           19.650000  1.687600e+02      2.964035
# 75%             17.700000           26.912500  4.428500e+02      3.850000
# max          10953.500000        84235.625000  1.663890e+06  10953.500000
#
#           Price_25q     Price_50q     Price_75q  AverageInvoiceCost  \
# count   5879.000000   5879.000000   5879.000000         5879.000000
# mean       6.218396      7.550029      9.495038          391.836598
# std      174.202780    176.853961    179.569531         1214.996998
# min        0.080000      0.130000      0.170000            2.950000
# 25%        0.850000      1.650000      2.750000          181.655000
# 50%        1.250000      1.950000      3.750000          285.076000
# 75%        1.650000      2.762500      4.950000          420.596667
# max    10953.500000  10953.500000  10953.500000        84236.250000
#
#        InvoiceCount  Timestamp_diff    Frequency
# count   5879.000000     5879.000000  5879.000000
# mean       6.817146      269.637693     0.028820
# std       42.505382      255.444652     0.156604
# min        1.000000        0.000000     0.000000
# 25%        1.000000        0.000000     0.000000
# 50%        3.000000      218.000000     0.011976
# 75%        7.000000      505.000000     0.024108
# max     3109.000000      728.000000     6.000000

# %%
try:
    for_clustering.drop(columns=["Cluster"],inplace=True)
except:
    pass

scaler=StandardScaler()
for_clustering_scaled=scaler.fit_transform(for_clustering)

# %%
sil_scores = []
K_range = range(2, 10)  

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(for_clustering_scaled)
    sil = silhouette_score(for_clustering_scaled, labels)
    sil_scores.append(sil)


plt.plot(K_range, sil_scores, marker='o')
plt.xlabel("Number of clusters (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis for Optimal K")
plt.show()

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
labels = kmeans.fit_predict(for_clustering_scaled)

for_clustering["Cluster"]=labels

# %%
for_clustering[for_clustering["Cluster"]==0].describe()
# Out:
#         Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count    5877.000000    5877.000000   5877.000000   5877.000000   5877.000000
# mean     1943.219840      25.318842     10.630551     15.738557     31.219032
# std     12910.612838     365.057944     60.447370     76.933064    541.791275
# min         1.000000       1.000000      1.000000      1.000000      1.000000
# 25%       190.000000       5.597403      2.000000      3.000000      6.000000
# 50%       492.000000       9.594203      4.000000      6.500000     12.000000
# 75%      1377.000000      14.151239      6.000000     12.000000     16.000000
# max    714139.000000   26999.000000   2000.000000   2520.000000  40498.000000
#
#        Timestamp_min  TotalStockCost_sum  TotalStockCost_mean  \
# count    5877.000000        5.877000e+03          5877.000000
# mean      261.471329        3.564420e+03            45.262785
# std       220.118807        4.459368e+04           761.844856
# min         1.000000        2.950000e+00             2.042182
# 25%        69.000000        3.487500e+02            11.469000
# 50%       207.000000        8.988700e+02            17.350000
# 75%       420.000000        2.304180e+03            24.155833
# max       729.000000        3.229539e+06         56157.500000
#
#        TotalStockCost_25q  TotalStockCost_50q  ...     Price_sum   Price_mean  \
# count         5877.000000         5877.000000  ...  5.877000e+03  5877.000000
# mean            20.752951           27.433243  ...  7.184044e+02     5.535881
# std             98.919094          113.998293  ...  2.173899e+04    49.775058
# min              0.390000            0.790000  ...  1.700000e-01     0.151333
# 25%              4.250000            7.950000  ...  6.528000e+01     2.292036
# 50%             12.500000           15.300000  ...  1.683900e+02     2.963905
# 75%             15.000000           17.700000  ...  4.427000e+02     3.849783
# max           3861.000000         4388.500000  ...  1.663890e+06  2033.100000
#
#          Price_25q    Price_50q    Price_75q  AverageInvoiceCost  \
# count  5877.000000  5877.000000  5877.000000         5877.000000
# mean      3.172755     4.504841     6.450512          388.922187
# std      41.562089    51.638685    60.387308         1204.321431
# min       0.080000     0.130000     0.170000            2.950000
# 25%       0.850000     1.650000     2.750000          181.650000
# 50%       1.250000     1.950000     3.750000          285.065000
# 75%       1.650000     2.750000     4.950000          420.500000
# max    2033.100000  2225.170000  2732.875000        84236.250000
#
#        InvoiceCount  Timestamp_diff    Frequency  Cluster
# count   5877.000000     5877.000000  5877.000000   5877.0
# mean       6.818955      269.729454     0.028829      0.0
# std       42.512500      255.439671     0.156630      0.0
# min        1.000000        0.000000     0.000000      0.0
# 25%        1.000000        0.000000     0.000000      0.0
# 50%        3.000000      218.000000     0.011976      0.0
# 75%        7.000000      505.000000     0.024119      0.0
# max     3109.000000      728.000000     6.000000      0.0
#
# [8 rows x 21 columns]

# %%
for_clustering[for_clustering["Cluster"]==1].describe()
# Out:
#        Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count      2.000000            2.0           2.0           2.0           2.0
# mean       1.500000            1.0           1.0           1.0           1.0
# std        0.707107            0.0           0.0           0.0           0.0
# min        1.000000            1.0           1.0           1.0           1.0
# 25%        1.250000            1.0           1.0           1.0           1.0
# 50%        1.500000            1.0           1.0           1.0           1.0
# 75%        1.750000            1.0           1.0           1.0           1.0
# max        2.000000            1.0           1.0           1.0           1.0
#
#        Timestamp_min  TotalStockCost_sum  TotalStockCost_mean  \
# count       2.000000            2.000000             2.000000
# mean      111.000000        12434.920000          8955.835000
# std         2.828427         2095.044256          2825.124936
# min       109.000000        10953.500000          6958.170000
# 25%       110.000000        11694.210000          7957.002500
# 50%       111.000000        12434.920000          8955.835000
# 75%       112.000000        13175.630000          9954.667500
# max       113.000000        13916.340000         10953.500000
#
#        TotalStockCost_25q  TotalStockCost_50q  ...     Price_sum  \
# count            2.000000            2.000000  ...      2.000000
# mean          8955.835000         8955.835000  ...  12434.920000
# std           2825.124936         2825.124936  ...   2095.044256
# min           6958.170000         6958.170000  ...  10953.500000
# 25%           7957.002500         7957.002500  ...  11694.210000
# 50%           8955.835000         8955.835000  ...  12434.920000
# 75%           9954.667500         9954.667500  ...  13175.630000
# max          10953.500000        10953.500000  ...  13916.340000
#
#          Price_mean     Price_25q     Price_50q     Price_75q  \
# count      2.000000      2.000000      2.000000      2.000000
# mean    8955.835000   8955.835000   8955.835000   8955.835000
# std     2825.124936   2825.124936   2825.124936   2825.124936
# min     6958.170000   6958.170000   6958.170000   6958.170000
# 25%     7957.002500   7957.002500   7957.002500   7957.002500
# 50%     8955.835000   8955.835000   8955.835000   8955.835000
# 75%     9954.667500   9954.667500   9954.667500   9954.667500
# max    10953.500000  10953.500000  10953.500000  10953.500000
#
#        AverageInvoiceCost  InvoiceCount  Timestamp_diff  Frequency  Cluster
# count            2.000000      2.000000             2.0        2.0      2.0
# mean          8955.835000      1.500000             0.0        0.0      1.0
# std           2825.124936      0.707107             0.0        0.0      0.0
# min           6958.170000      1.000000             0.0        0.0      1.0
# 25%           7957.002500      1.250000             0.0        0.0      1.0
# 50%           8955.835000      1.500000             0.0        0.0      1.0
# 75%           9954.667500      1.750000             0.0        0.0      1.0
# max          10953.500000      2.000000             0.0        0.0      1.0
#
# [8 rows x 21 columns]

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=20)
outliers = lof.fit_predict(for_clustering_scaled)   # -1 = outlier, 1 = inlier
for_clustering_clean = for_clustering_scaled[outliers == 1]

# %%
from collections import Counter
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(for_clustering_clean)

print(Counter(list(labels)))
# Out:
# Counter({np.int32(2): 2016, np.int32(0): 1980, np.int32(1): 1351})

# %%
print(silhouette_score(for_clustering_clean, labels))
# Out:
# 0.4327413290349169

# %%
for_clustering_clean[labels==0]
# Out:
# array([[-0.13523743, -0.03759903,  0.02271512, ..., -0.13686833,
#         -1.05565188, -0.18404495],
#        [-0.09440804, -0.05009094, -0.12621209, ...,  0.07488758,
#          0.31853956, -0.00210521],
#        [-0.11889018, -0.02074565,  0.02271512, ..., -0.1133399 ,
#         -0.54277701, -0.08654747],
#        ...,
#        [-0.12640527, -0.05082596, -0.13862269, ..., -0.1133399 ,
#         -0.72678556, -0.03199531],
#        [-0.14368222, -0.04743075, -0.10966462, ..., -0.13686833,
#         -1.05565188, -0.18404495],
#        [-0.14252009, -0.04583243, -0.14275956, ..., -0.1133399 ,
#         -0.59758807, -0.0748811 ]])

# %%
for_clustering[outliers==1][labels==0].describe()
# Out:
#         Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count    1980.000000    1980.000000   1980.000000   1980.000000   1980.000000
# mean     2597.438889      14.004352      5.737500      9.835101     16.643056
# std      5550.753377      31.522509     16.000357     23.457189     42.528776
# min         9.000000       1.105691      1.000000      1.000000      1.000000
# 25%       678.250000       5.929472      2.000000      3.000000      6.000000
# 50%      1441.000000       9.871791      4.000000      6.000000     12.000000
# 75%      2921.250000      14.003247      6.000000     12.000000     16.000000
# max    119656.000000     656.666667    325.000000    480.000000   1000.000000
#
#        Timestamp_min  TotalStockCost_sum  TotalStockCost_mean  \
# count    1980.000000         1980.000000          1980.000000
# mean       83.026768         4513.356894            23.326089
# std        78.098956         8212.083170            33.206723
# min         1.000000           30.950000             2.042182
# 25%        10.000000         1265.245000            11.339503
# 50%        64.000000         2560.595000            17.817604
# 75%       131.000000         5060.317500            23.992408
# max       311.000000       175603.550000           626.266667
#
#        TotalStockCost_25q  TotalStockCost_50q  ...    Price_sum   Price_mean  \
# count         1980.000000         1980.000000  ...  1980.000000  1980.000000
# mean            12.034922           17.467614  ...   739.904687     3.248651
# std             21.070070           29.822251  ...   798.597444     1.581264
# min              0.850000            1.650000  ...     1.700000     0.376250
# 25%              3.900000            7.793750  ...   234.720000     2.458080
# 50%             11.152500           15.300000  ...   488.290000     2.969651
# 75%             14.980000           17.700000  ...   933.292500     3.688455
# max            417.600000          625.000000  ...  6720.760000    28.199778
#
#          Price_25q    Price_50q    Price_75q  AverageInvoiceCost  \
# count  1980.000000  1980.000000  1980.000000         1980.000000
# mean      1.263282     2.175581     3.907768          372.862381
# std       0.566994     0.945787     1.634034          239.183203
# min       0.170000     0.170000     0.400000            7.737500
# 25%       0.850000     1.650000     2.950000          221.924314
# 50%       1.250000     1.950000     3.750000          316.739524
# 75%       1.450000     2.550000     4.950000          449.536000
# max      12.487500    15.975000    18.487500         2926.725833
#
#        InvoiceCount  Timestamp_diff    Frequency  Cluster
# count   1980.000000     1980.000000  1980.000000   1980.0
# mean      10.920707      566.443939     0.018372      0.0
# std       10.276977      112.565410     0.014845      0.0
# min        2.000000      264.000000     0.002841      0.0
# 25%        5.000000      479.000000     0.009040      0.0
# 50%        8.000000      580.000000     0.014200      0.0
# 75%       13.000000      666.250000     0.022126      0.0
# max      127.000000      728.000000     0.175172      0.0
#
# [8 rows x 21 columns]

# %%
for_clustering[outliers==1][labels==1].describe()
# Out:
#        Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count   1351.000000    1351.000000   1351.000000   1351.000000   1351.000000
# mean     495.039970      13.422414      7.655625     10.815322     15.686528
# std     1055.566883      31.583005     24.821686     27.934847     40.722752
# min        1.000000       1.000000      1.000000      1.000000      1.000000
# 25%      133.500000       6.026455      2.000000      4.000000      6.000000
# 50%      280.000000       9.344262      4.000000      7.000000     12.000000
# 75%      570.000000      12.602823      6.000000     12.000000     12.000000
# max    32184.000000     715.200000    504.000000    504.000000   1152.000000
#
#        Timestamp_min  TotalStockCost_sum  TotalStockCost_mean  \
# count    1351.000000         1351.000000          1351.000000
# mean      582.254626          795.250371            22.219522
# std        95.346792         1156.751870            41.263172
# min       395.000000            3.750000             2.264375
# 25%       491.000000          224.030000            11.877282
# 50%       597.000000          460.400000            16.749286
# 75%       668.000000          980.150000            20.514604
# max       729.000000        26626.800000           615.750000
#
#        TotalStockCost_25q  TotalStockCost_50q  ...    Price_sum   Price_mean  \
# count         1351.000000         1351.000000  ...  1351.000000  1351.000000
# mean            14.651445           18.602424  ...   167.124871     3.332868
# std             34.692291           37.872008  ...   239.451000     2.120294
# min              0.580000            1.250000  ...     0.390000     0.390000
# 25%              4.950000            9.260000  ...    44.985000     2.143333
# 50%             12.000000           15.150000  ...    95.550000     2.942941
# 75%             15.000000           17.400000  ...   196.550000     3.886005
# max            550.800000          615.750000  ...  4419.590000    32.971429
#
#          Price_25q    Price_50q    Price_75q  AverageInvoiceCost  \
# count  1351.000000  1351.000000  1351.000000         1351.000000
# mean      1.380722     2.297768     3.977500          327.196956
# std       1.014729     1.374158     2.134949          250.417620
# min       0.190000     0.290000     0.390000            3.750000
# 25%       0.850000     1.497500     2.550000          164.840000
# 50%       1.250000     1.950000     3.750000          266.650000
# 75%       1.650000     2.890000     4.950000          403.386667
# max      12.750000    12.750000    13.700000         1862.000000
#
#        InvoiceCount  Timestamp_diff    Frequency  Cluster
# count   1351.000000     1351.000000  1351.000000   1351.0
# mean       2.378979       57.792746     0.025575      0.0
# std        2.140952       78.672212     0.040142      0.0
# min        1.000000        0.000000     0.000000      0.0
# 25%        1.000000        0.000000     0.000000      0.0
# 50%        2.000000       11.000000     0.009009      0.0
# 75%        3.000000      100.000000     0.037500      0.0
# max       22.000000      299.000000     0.285714      0.0
#
# [8 rows x 21 columns]

# %%
for_clustering[outliers==1][labels==2].describe()
# Out:
#        Quantity_sum  Quantity_mean  Quantity_25q  Quantity_50q  Quantity_75q  \
# count   2016.000000    2016.000000   2016.000000   2016.000000   2016.000000
# mean     456.386409      12.273698      6.994048      9.973710     14.457465
# std      591.850253      28.274404     24.690492     29.682544     33.840499
# min        1.000000       1.000000      1.000000      1.000000      1.000000
# 25%      125.000000       4.591864      1.000000      2.000000      5.000000
# 50%      263.000000       8.566202      3.500000      6.000000     12.000000
# 75%      551.250000      12.185550      6.000000     12.000000     12.000000
# max     6967.000000     735.428571    594.000000    876.000000    966.000000
#
#        Timestamp_min  TotalStockCost_sum  TotalStockCost_mean  \
# count    2016.000000         2016.000000          2016.000000
# mean      220.030258          789.856326            21.110884
# std       115.761561          964.645310            42.229082
# min         1.000000            2.950000             2.308947
# 25%       119.000000          241.675000             9.301661
# 50%       243.000000          474.065000            16.200058
# 75%       321.000000          998.752500            20.500568
# max       429.000000        11959.270000           856.005000
#
#        TotalStockCost_25q  TotalStockCost_50q  ...    Price_sum   Price_mean  \
# count         2016.000000         2016.000000  ...  2016.000000  2016.000000
# mean            14.051507           17.797572  ...   180.826787     3.351309
# std             36.120901           40.795194  ...   233.764487     3.033941
# min              0.850000            1.250000  ...     0.290000     0.290000
# 25%              3.734375            6.300000  ...    49.837500     2.278288
# 50%             11.550000           15.000000  ...   107.170000     2.968194
# 75%             14.962500           17.400000  ...   224.535000     3.877402
# max            715.550000          809.510000  ...  2607.200000   115.800000
#
#          Price_25q    Price_50q    Price_75q  AverageInvoiceCost  \
# count  2016.000000  2016.000000  2016.000000         2016.000000
# mean      1.480980     2.428120     4.099095          291.279271
# std       1.579031     2.872364     4.295258          196.999823
# min       0.200000     0.210000     0.290000            2.950000
# 25%       0.850000     1.650000     2.850000          159.538750
# 50%       1.250000     2.025000     3.750000          245.886000
# 75%       1.650000     2.950000     4.950000          359.200000
# max      58.700000   115.800000   172.900000         2255.880000
#
#        InvoiceCount  Timestamp_diff    Frequency  Cluster
# count   2016.000000     2016.000000  2016.000000   2016.0
# mean       2.657738      132.505952     0.015057      0.0
# std        2.359484      144.001640     0.026096      0.0
# min        1.000000        0.000000     0.000000      0.0
# 25%        1.000000        0.000000     0.000000      0.0
# 50%        2.000000       79.000000     0.008174      0.0
# 75%        3.000000      263.250000     0.018784      0.0
# max       23.000000      419.000000     0.285714      0.0
#
# [8 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np


pca = PCA().fit(for_clustering_clean)

# Cumulative explained variance
cum_var = np.cumsum(pca.explained_variance_ratio_)

# Plot cumulative variance
plt.figure(figsize=(8,5))
plt.plot(cum_var, marker='o')
plt.axhline(y=0.95, color='r', linestyle='--')  # 95% threshold
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Explained Variance")
plt.grid(True)
plt.show()

# Find minimum components that explain 95% variance
n_components_95 = np.argmax(cum_var >= 0.95) + 1
print(f"Optimal number of components for 95% variance: {n_components_95}")
# Out:
# Optimal number of components for 95% variance: 4

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(for_clustering_clean)
sil_scores = []
K_range = range(2, 10)  

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_pca)
    sil = silhouette_score(X_pca, labels)
    sil_scores.append(sil)


plt.plot(K_range, sil_scores, marker='o')
plt.xlabel("Number of clusters (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis for Optimal K")
plt.show()
